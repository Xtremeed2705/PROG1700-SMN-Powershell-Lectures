# %%
Write-Host "Hello World!"
# Out:
# Hello World!

# %%
$name = "Brian Shewan"
Write-Host $name
# Out:
# Brian Shewan

# %%
Write-Host "Hello," $name
# Out:
# Hello, Brian Shewan

# %%
2 + 2
# Out:
# 4

# %%
Write-Host 2 + 2
# Out:
# 2 + 2

# %%
Write-Host (2 + 2)
# Out:
# 4

# %%
4 - 2
# Out:
# 2

# %%
5 * 2
# Out:
# 10

# %%
10 / 5
# Out:
# 2

# %%
# modulus division gives you the remainder of a long division
5 % 2
# Out:
# 1

# %%
# exponents (using the .Net Math library)
[Math]::pow(2,3)
# Out:
# 8

# %%
# get the value of Pi
[Math]::PI
# Out:
# 3.14159265358979

# %%
# square roots
[Math]::sqrt(25)
# Out:
# 5

# %%
# remove decimal from answer
[Math]::floor(5 / 2)
# Out:
# 2

# %%
# remove decimal and move to next value
[Math]::ceiling(5 / 2)
# Out:
# 3

# %%
# rounding a decimal
[Math]::round([Math]::PI, 5)
# Out:
# 3.14159

# %%
# to use hexadecimal values
$number = 12345
$hexadecimal = 0x12345
Write-Host $number, $hexadecimal
# Out:
# 12345 74565

# %%
2 + "8"
# Out:
# 10

# %%
2 + "8X"
# Out:
# InvalidArgument: Cannot convert value "8X" to type "System.Int32". Error: "Input string was not in a correct format."

# %%
# string concatenation
"2" + "8X"
# Out:
# 28X

# %%
# simple writing
Write-Host "Simple"
# Out:
# Simple

# %%
# write a variable
$course = "PROG1700"
Write-Host $course
# Out:
# PROG1700

# %%
# write multiple items
Write-Host "Separated" "with" "spaces"
Write-Host "Separated", "with", "commas"
Write-Host "String" 123 3.14159 $true
# Out:
# Separated with spaces
# Separated with commas
# String 123 3.14159 True

# %%
# mathematical expressions
Write-Host 1 + 2
Write-Host (1 + 2)
# Out:
# 1 + 2
# 3

# %%
# repeating
Write-Host ("*" * 40)
# Out:
# ****************************************

# %%
# variable substitution
$firstName = "Bob"
$lastName = "Smith"
$studentID = "W123456"
Write-Host "First:" $firstName ", Last:" $lastName ", ID:" $studentID
Write-Host ("First: {0}, Last: {1}, ID: {2}" -f $firstName, $lastName, $studentID)
Write-Host "First: $firstName, Last: $lastName, ID: $studentID"
# Out:
# First: Bob , Last: Smith , ID: W123456
# First: Bob, Last: Smith, ID: W123456
# First: Bob, Last: Smith, ID: W123456

# %%
# less carriage returns
Write-Host "1 + 2 = " -NoNewLine
Write-Host (1 + 2)
# Out:
# 1 + 2 = 3

# %%
# more carriage returns
Write-Host "This is a poem that`nshould be on two lines."
# Out:
# This is a poem that
# should be on two lines.
